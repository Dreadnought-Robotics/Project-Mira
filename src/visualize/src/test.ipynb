# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16,12]

dt = 0.001
t = np.arange(0,1,dt)
f = np.sin(2*np.pi*50*t) + np.sin(2*np.pi*120*t)
f_clean = f
f = f+ 2.5*np.random.randn(len(t))

plt.plot(t, f, label = 'Noisy')
plt.plot(t, f_clean, label = 'Clean')
plt.xlim(t[0], t[-1])
plt.legend()

# %%
n = len(t)
f_hat = np.fft.fft(f, n)
PSD = f_hat * np.conj(f_hat) / n
freq = (1/(dt*n)) * np.arange(n)
L = np.arange(1, np.floor(n/2), dtype = 'int')

fig, axs = plt.subplots(2, 1)

plt.sca(axs[0])
plt.plot(t, f, label = 'Noisy')
plt.plot(t, f_clean, label = 'Clean')
plt.xlim(t[0], t[-1])
plt.legend()

plt.sca(axs[1])
plt.plot(freq[L], PSD[L], label = 'Noisy')
plt.xlim(freq[L[0]], freq[L[-1]])
plt.legend()

plt.show()
# Out:
# /home/tonyox/.local/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
